# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:/Users/NITHIYAGOKULAVASAGI/Desktop/data.csv')
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.dtypes # it is used to show the datatypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df=df.drop(['Engine Fuel Type','Market Category','Vehicle Style','Popularity','Number of Doors'],axis=1)
df
# Out:
#           Make       Model  Year  Engine HP  Engine Cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       Transmission Type      Driven_Wheels Vehicle Size  highway MPG  \
# 0                MANUAL   rear wheel drive      Compact           26
# 1                MANUAL   rear wheel drive      Compact           28
# ...

# %%
df = df.rename(columns={"Engine HP":"HP","Engine Cylinders":"Cylinders"})
df.head()
# Out:
#   Make       Model  Year     HP  Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011  335.0        6.0            MANUAL
# 1  BMW    1 Series  2011  300.0        6.0            MANUAL
# 2  BMW    1 Series  2011  300.0        6.0            MANUAL
# 3  BMW    1 Series  2011  230.0        6.0            MANUAL
# 4  BMW    1 Series  2011  230.0        6.0            MANUAL
#
#       Driven_Wheels Vehicle Size  highway MPG  city mpg   MSRP
# 0  rear wheel drive      Compact           26        19  46135
# 1  rear wheel drive      Compact           28        19  40650
# 2  rear wheel drive      Compact           28        20  36350
# 3  rear wheel drive      Compact           28        18  29450
# 4  rear wheel drive      Compact           28        18  34500

# %%
df.shape
# Out:
# (11914, 11)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows",duplicate_rows_df.shape)
# Out:
# number of duplicate rows (970, 11)

# %%
df.count() # used to count the rows after duplicated values removed
# Out:
# Make                 11914
# Model                11914
# Year                 11914
# HP                   11845
# Cylinders            11884
# Transmission Type    11914
# Driven_Wheels        11914
# Vehicle Size         11914
# highway MPG          11914
# city mpg             11914
# MSRP                 11914
# dtype: int64

# %%
df = df.drop_duplicates() # it is used to drop the duplicate values
df.head()
# Out:
#   Make       Model  Year     HP  Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011  335.0        6.0            MANUAL
# 1  BMW    1 Series  2011  300.0        6.0            MANUAL
# 2  BMW    1 Series  2011  300.0        6.0            MANUAL
# 3  BMW    1 Series  2011  230.0        6.0            MANUAL
# 4  BMW    1 Series  2011  230.0        6.0            MANUAL
#
#       Driven_Wheels Vehicle Size  highway MPG  city mpg   MSRP
# 0  rear wheel drive      Compact           26        19  46135
# 1  rear wheel drive      Compact           28        19  40650
# 2  rear wheel drive      Compact           28        20  36350
# 3  rear wheel drive      Compact           28        18  29450
# 4  rear wheel drive      Compact           28        18  34500

# %%
print(df.isnull().sum())
# Out:
# Make                  0
# Model                 0
# Year                  0
# HP                   69
# Cylinders            30
# Transmission Type     0
# Driven_Wheels         0
# Vehicle Size          0
# highway MPG           0
# city mpg              0
# MSRP                  0
# dtype: int64

# %%
df = df.dropna()
df.count()
# Out:
# Make                 10846
# Model                10846
# Year                 10846
# HP                   10846
# Cylinders            10846
# Transmission Type    10846
# Driven_Wheels        10846
# Vehicle Size         10846
# highway MPG          10846
# city mpg             10846
# MSRP                 10846
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Make                 0
# Model                0
# Year                 0
# HP                   0
# Cylinders            0
# Transmission Type    0
# Driven_Wheels        0
# Vehicle Size         0
# highway MPG          0
# city mpg             0
# MSRP                 0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.subplots(figsize=(10,6))
plt.hist(df["Year"])
plt.xlabel("Year")
plt.ylabel("No.of Cars")
plt.show()
